# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#lendo o arquivo
concrete = pd.read_csv('concrete.csv', sep = ',', encoding='latin-1')

# %%
concrete
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28  \
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# ...

# %%
concrete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cement        1030 non-null   float64
#  1   slag          1030 non-null   float64
#  2   ash           1030 non-null   float64
#  3   water         1030 non-null   float64
#  4   superplastic  1030 non-null   float64
#  5   coarseagg     1030 non-null   float64
#  6   fineagg       1030 non-null   float64
#  7   age           1030 non-null   int64
#  8   strength      1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %% [markdown]
# Conferindo dados ausentes:

# %%
concrete.isnull().sum()
# Out:
# cement          0
# slag            0
# ash             0
# water           0
# superplastic    0
# coarseagg       0
# fineagg         0
# age             0
# strength        0
# dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.title('Histograma de Resistência à Compressão do Concreto ')
sns.histplot(data=concrete,x='strength', kde=True);

# %%
plt.figure(figsize=(20,10))
plt.title('Boxplot of Dataset')
sns.boxplot(data=concrete);

# %%
plt.figure(figsize=(20,10))
plt.title('Boxplot of slag')
sns.boxplot(data=concrete, x='slag');

# %%
concrete[concrete['slag'] > 350]
# Out:
#      cement   slag  ash  water  superplastic  coarseagg  fineagg  age
# 918   239.6  359.4  0.0  185.7           0.0      941.6    664.3   28  \
# 990   239.6  359.4  0.0  185.7           0.0      941.6    664.3    7
#
#      strength
# 918     39.44
# 990     25.42

# %%
concrete = concrete.drop(concrete[concrete['slag'] > 350].index)

# %%
plt.figure(figsize=(20,10))
plt.title('Boxplot of water')
sns.boxplot(data=concrete, x='water');

# %%
concrete[(concrete['water'] < 122) | (concrete['water'] > 230)]
# Out:
#      cement   slag    ash  water  superplastic  coarseagg  fineagg  age
# 66    237.0   92.0   71.0  247.0           6.0      853.0    695.0   28  \
# 263   236.9   91.7   71.5  246.9           6.0      852.9    695.4   28
# 432   168.0   42.1  163.8  121.8           5.7     1058.7    780.1   28
# 462   168.0   42.1  163.8  121.8           5.7     1058.7    780.1  100
# 587   168.0   42.1  163.8  121.8           5.7     1058.7    780.1    3
# 740   140.0  164.0  128.0  237.0           6.0      869.0    656.0   28
# 789   168.0   42.1  163.8  121.8           5.7     1058.7    780.1   56
# 826   139.7  163.9  127.7  236.7           5.8      868.6    655.6   28
# 914   168.0   42.1  163.8  121.8           5.7     1058.7    780.1   14
#
#      strength
# 66      28.63
# 263     28.63
# 432     24.24
# 462     39.23
# 587      7.75
# 740     35.23
# 789     32.85
# 826     35.23
# 914     17.82

# %%
concrete= concrete.drop(concrete[(concrete['water'] < 122) | (concrete['water'] > 230)] .index)

# %%
plt.figure(figsize=(20,10))
plt.title('Boxplot of superplastic')
sns.boxplot(data=concrete, x='superplastic');

# %%
concrete['superplastic'].describe()
# Out:
# count    1019.000000
# mean        6.220314
# std         5.999582
# min         0.000000
# 25%         0.000000
# 50%         6.500000
# 75%        10.300000
# max        32.200000
# Name: superplastic, dtype: float64

# %%
concrete[concrete['superplastic'] > 25]
# Out:
#       cement   slag  ash  water  superplastic  coarseagg  fineagg  age
# 44     531.3    0.0  0.0  141.8          28.2      852.1    893.7   91  \
# 156    531.3    0.0  0.0  141.8          28.2      852.1    893.7   28
# 232    469.0  117.2  0.0  137.8          32.2      852.1    840.5   56
# 292    469.0  117.2  0.0  137.8          32.2      852.1    840.5   91
# 538    531.3    0.0  0.0  141.8          28.2      852.1    893.7    7
# 744    469.0  117.2  0.0  137.8          32.2      852.1    840.5    7
# 816    469.0  117.2  0.0  137.8          32.2      852.1    840.5   28
# 838    531.3    0.0  0.0  141.8          28.2      852.1    893.7   56
# 955    469.0  117.2  0.0  137.8          32.2      852.1    840.5    3
# 1026   531.3    0.0  0.0  141.8          28.2      852.1    893.7    3
#
#       strength
# 44        59.2
# 156       56.4
# 232       69.3
# 292       70.7
# 538       46.9
# 744       54.9
# 816       66.9
# 838       58.8
# 955       40.2
# 1026      41.3

# %%
concrete = concrete.drop(concrete[concrete['superplastic'] > 25].index)

# %%
plt.figure(figsize=(20,10))
plt.title('Boxplot of fineagg')
sns.boxplot(data=concrete, x='fineagg');

# %%
concrete[(concrete['fineagg'] < 600) | (concrete['fineagg'] > 950)]
# Out:
#      cement   slag  ash  water  superplastic  coarseagg  fineagg  age
# 13    237.5  237.5  0.0  228.0           0.0      932.0    594.0    7  \
# 16    237.5  237.5  0.0  228.0           0.0      932.0    594.0   28
# 31    475.0    0.0  0.0  228.0           0.0      932.0    594.0   28
# 64    332.5  142.5  0.0  228.0           0.0      932.0    594.0  365
# 93    427.5   47.5  0.0  228.0           0.0      932.0    594.0  180
# 99    237.5  237.5  0.0  228.0           0.0      932.0    594.0  180
# 129   375.0   93.8  0.0  126.6          23.4      852.1    992.6   91
# 142   332.5  142.5  0.0  228.0           0.0      932.0    594.0   90
# 149   380.0   95.0  0.0  228.0           0.0      932.0    594.0  270
# 241   427.5   47.5  0.0  228.0           0.0      932.0    594.0   90
# 283   475.0    0.0  0.0  228.0           0.0      932.0    594.0   90
# 297   475.0    0.0  0.0  228.0           0.0      932.0    594.0  270
# ...

# %%
concrete = concrete.drop(concrete[(concrete['fineagg'] < 600) | (concrete['fineagg'] > 950)].index)

# %%
plt.figure(figsize=(20,10))
plt.title('Boxplot of age')
sns.boxplot(data=concrete, x='age');

# %%
concrete[concrete['age'] > 150]
# Out:
#       cement   slag  ash  water  superplastic  coarseagg  fineagg  age
# 51     331.0    0.0  0.0  192.0           0.0      978.0    825.0  180  \
# 103    380.0    0.0  0.0  228.0           0.0      932.0    670.0  180
# 133    236.0    0.0  0.0  193.0           0.0      968.0    885.0  365
# 144    302.0    0.0  0.0  203.0           0.0      974.0    817.0  180
# 152    322.0    0.0  0.0  203.0           0.0      974.0    800.0  180
# 157    198.6  132.4  0.0  192.0           0.0      978.4    825.5  360
# 159    304.0   76.0  0.0  228.0           0.0      932.0    670.0  365
# 198    266.0  114.0  0.0  228.0           0.0      932.0    670.0  365
# 199    277.0    0.0  0.0  191.0           0.0      968.0    856.0  180
# 207    190.0  190.0  0.0  228.0           0.0      932.0    670.0  180
# 256    525.0    0.0  0.0  189.0           0.0     1125.0    613.0  270
# 262    266.0  114.0  0.0  228.0           0.0      932.0    670.0  270
# ...

# %%
concrete = concrete.drop(concrete[concrete['age'] > 150].index)

# %%
plt.figure(figsize=(20,10))
plt.title('Boxplot of strength')
sns.boxplot(data=concrete, x='strength');

# %%
concrete['strength'].describe()
# Out:
# count    930.000000
# mean      35.074548
# std       16.953394
# min        2.330000
# 25%       22.492500
# 50%       33.400000
# 75%       45.352500
# max       82.600000
# Name: strength, dtype: float64

# %%
concrete[concrete['strength'] > 79]
# Out:
#       cement   slag  ash  water  superplastic  coarseagg  fineagg  age
# 192    315.0  137.0  0.0  145.0           5.9     1130.0    745.0   28  \
# 245    362.6  189.0  0.0  164.9          11.6      944.7    755.8   91
# 257    389.9  189.0  0.0  145.9          22.0      944.7    755.8   56
# 493    362.6  189.0  0.0  164.9          11.6      944.7    755.8   91
# 732    540.0    0.0  0.0  162.0           2.5     1040.0    676.0   28
# 733    362.6  189.0  0.0  164.9          11.6      944.7    755.8   91
# 766    362.6  189.0  0.0  164.9          11.6      944.7    755.8   91
# 950    389.9  189.0  0.0  145.9          22.0      944.7    755.8   91
# 1003   323.7  282.8  0.0  183.8          10.3      942.7    659.9   56
#
#       strength
# 192      81.75
# 245      79.30
# 257      79.40
# 493      79.30
# 732      79.99
# 733      79.30
# 766      79.30
# 950      82.60
# 1003     80.20

# %%
concrete = concrete.drop(concrete[concrete['strength'] > 79].index)

# %%
concrete
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28  \
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1023   141.3  212.0    0.0  203.5           0.0      971.8    748.5    7
# 1024   297.2    0.0  117.5  174.8           9.5     1022.8    753.5    3
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# ...

# %%
plt.figure(figsize=(20,10))
plt.title('Plot of cement vs strength')
sns.scatterplot(data=concrete, x='cement', y= 'strength');

# %%
plt.figure(figsize=(20,10))
plt.title('Plot of slag vs strength')
sns.scatterplot(data=concrete, x='slag', y= 'strength');

# %%
plt.figure(figsize=(20,10))
plt.title('Plot of ash vs strength')
sns.scatterplot(data=concrete, x='ash', y= 'strength');

# %%
plt.figure(figsize=(20,10))
plt.title('Plot of water vs strength')
sns.scatterplot(data=concrete, x='water', y= 'strength');

# %%
plt.figure(figsize=(20,10))
plt.title('Plot of coarseagg vs strength')
sns.scatterplot(data=concrete, x='coarseagg', y= 'strength');

# %%
plt.figure(figsize=(20,10))
plt.title('Plot of fineagg vs strength')
sns.scatterplot(data=concrete, x='fineagg', y= 'strength');

# %%
plt.figure(figsize=(20,10))
plt.title('Plot of age vs strength')
sns.scatterplot(data=concrete, x='age', y= 'strength');

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data=concrete.corr(), annot=True);

# %%
concrete.corr()['strength'].sort_values()[:-1]
# Out:
# water          -0.385794
# coarseagg      -0.165909
# fineagg        -0.161633
# ash            -0.042227
# slag            0.129455
# superplastic    0.398849
# cement          0.476464
# age             0.509746
# Name: strength, dtype: float64
